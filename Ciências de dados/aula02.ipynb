# %%
import matplotlib.pyplot as plt

notas = [5, 7, 8, 6, 9, 10, 4, 8, 7, 6]

plt.hist(notas, color='#000099', edgecolor='#000000')

plt.title('Distribuição de Notas dos Alunos na Atividade')
plt.xlabel('Notas')
plt.ylabel('Quantidade de Alunos')
plt.yticks(range(1,4))

plt.show()
print("Perguntas: \nQual gráfico combina melhor com notas? \nOs dados são qualitativos ou quantitativos?")
print("histograma ou o gráfico de barras")
print("Os dados são quantitativos.")
# Out:
# Perguntas:
# Qual gráfico combina melhor com notas?
# Os dados são qualitativos ou quantitativos?
# histograma ou o gráfico de barras
# Os dados são quantitativos.
